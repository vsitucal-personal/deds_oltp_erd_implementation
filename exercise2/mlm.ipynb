# %% [markdown]
# # DEDS: Exercise 2
# Vincent Itucal

# %% [markdown]
# ## Updated ERD
#
# Removed the network tables and created self referencing foreign key `upline_id` that points to the primary key `marketer_id` representing the upline
# ![mlm.png](attachment:6a78a283-b92d-47d0-9e79-2a424e8009c2.png)

# %%
from faker import Faker
import random
import pandas as pd
from datetime import datetime, timedelta
from sqlalchemy import create_engine

# %%
# %load_ext sql

# %%
with open('../db_pass.txt', 'r') as file:
    db_password = file.read().strip()

# %%
connection_string = f"postgresql://vincent:{db_password}@sampledb.c34wykcu8liz.us-east-1.rds.amazonaws.com/mlm"

# %%
engine = create_engine(connection_string)

# %%
get_ipython().run_line_magic('sql', connection_string)
# Out:
# Connecting to 'postgresql://vincent:***@sampledb.c34wykcu8liz.us-east-1.rds.amazonaws.com/mlm'

# %% [markdown]
# ## Create Table Scripts

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS marketer (
#     marketer_id SERIAL PRIMARY KEY,
#     name VARCHAR(100) NOT NULL,
#     address TEXT,
#     contact_number VARCHAR(50),
#     upline_id INT,
#     FOREIGN KEY (upline_id) REFERENCES marketer(marketer_id)
# );
#
# CREATE TABLE IF NOT EXISTS products (
#     product_id SERIAL PRIMARY KEY,
#     product_name VARCHAR(100) NOT NULL,
#     product_description TEXT
# );
#
# CREATE TABLE IF NOT EXISTS sales (
#     sales_id SERIAL PRIMARY KEY,
#     marketer_id INT NOT NULL,
#     product_id INT NOT NULL,
#     quantity_sold INT NOT NULL,
#     sale_date DATE NOT NULL,
#     FOREIGN KEY (marketer_id) REFERENCES marketer(marketer_id),
#     FOREIGN KEY (product_id) REFERENCES products(product_id)
# );
# Out:
# Running query in 'postgresql://vincent:***@sampledb.c34wykcu8liz.us-east-1.rds.amazonaws.com/mlm'
# ++
# ||
# ++
# ++

# %% [markdown]
# ## List of Databases

# %%
# %sql \l
# Out:
# Running query in 'postgresql://vincent:***@sampledb.c34wykcu8liz.us-east-1.rds.amazonaws.com/mlm'
# +-----------+----------+----------+-------------+-------------+-----------------------+
# |    Name   |  Owner   | Encoding |   Collate   |    Ctype    |   Access privileges   |
# +-----------+----------+----------+-------------+-------------+-----------------------+
# |    mlm    | vincent  |   UTF8   | en_US.UTF-8 | en_US.UTF-8 |          None         |
# |  postgres | postgres |   UTF8   | en_US.UTF-8 | en_US.UTF-8 |          None         |
# |  rdsadmin | rdsadmin |   UTF8   | en_US.UTF-8 | en_US.UTF-8 | rdsadmin=CTc/rdsadmin |
# | template0 | rdsadmin |   UTF8   | en_US.UTF-8 | en_US.UTF-8 |      =c/rdsadmin      |
# |           |          |          |             |             | rdsadmin=CTc/rdsadmin |
# | template1 | postgres |   UTF8   | en_US.UTF-8 | en_US.UTF-8 |      =c/postgres      |
# |           |          |          |             |             | postgres=CTc/postgres |
# +-----------+----------+----------+-------------+-------------+-----------------------+

# %% [markdown]
# ## List of tables in mlm database

# %%
# %sql \dt
# Out:
# Running query in 'postgresql://vincent:***@sampledb.c34wykcu8liz.us-east-1.rds.amazonaws.com/mlm'
# +--------+----------+-------+---------+
# | Schema |   Name   |  Type |  Owner  |
# +--------+----------+-------+---------+
# | public | marketer | table | vincent |
# | public | products | table | vincent |
# | public |  sales   | table | vincent |
# +--------+----------+-------+---------+

# %% [markdown]
# ## Schema of tables

# %%
# %sqlcmd columns --table marketer
# Out:
# +----------------+--------------+----------+-----------------------------------------------+---------------+---------+
# |      name      |     type     | nullable |                    default                    | autoincrement | comment |
# +----------------+--------------+----------+-----------------------------------------------+---------------+---------+
# |  marketer_id   |   INTEGER    |  False   | nextval('marketer_marketer_id_seq'::regclass) |      True     |   None  |
# |      name      | VARCHAR(100) |  False   |                      None                     |     False     |   None  |
# |    address     |     TEXT     |   True   |                      None                     |     False     |   None  |
# | contact_number | VARCHAR(15)  |   True   |                      None                     |     False     |   None  |
# |   upline_id    |   INTEGER    |   True   |                      None                     |     False     |   None  |
# +----------------+--------------+----------+-----------------------------------------------+---------------+---------+

# %%
# %sqlcmd columns --table products
# Out:
# +---------------------+--------------+----------+----------------------------------------------+---------------+---------+
# |         name        |     type     | nullable |                   default                    | autoincrement | comment |
# +---------------------+--------------+----------+----------------------------------------------+---------------+---------+
# |      product_id     |   INTEGER    |  False   | nextval('products_product_id_seq'::regclass) |      True     |   None  |
# |     product_name    | VARCHAR(100) |  False   |                     None                     |     False     |   None  |
# | product_description |     TEXT     |   True   |                     None                     |     False     |   None  |
# +---------------------+--------------+----------+----------------------------------------------+---------------+---------+

# %%
# %sqlcmd columns --table sales
# Out:
# +---------------+---------+----------+-----------------------------------------+---------------+---------+
# |      name     |   type  | nullable |                 default                 | autoincrement | comment |
# +---------------+---------+----------+-----------------------------------------+---------------+---------+
# |    sales_id   | INTEGER |  False   | nextval('sales_sales_id_seq'::regclass) |      True     |   None  |
# |  marketer_id  | INTEGER |  False   |                   None                  |     False     |   None  |
# |   product_id  | INTEGER |  False   |                   None                  |     False     |   None  |
# | quantity_sold | INTEGER |  False   |                   None                  |     False     |   None  |
# |   sale_date   |   DATE  |  False   |                   None                  |     False     |   None  |
# +---------------+---------+----------+-----------------------------------------+---------------+---------+

# %% [markdown]
# ## Faker to create dummy data

# %%
fake = Faker()

# Number of records to generate
num_marketers = 100
num_products = 50
num_sales = 500

# Create marketers
marketers = []
for i in range(1, num_marketers + 1):
    marketers.append({
        'marketer_id': i,
        'name': fake.name(),
        'address': fake.address(),
        'contact_number': fake.phone_number(),
        'upline_id': random.randint(1, i - 1) if i > 1 else None  # Ensure valid upline_id or None
})

# Create products
products = []
for i in range(1, num_products + 1):
    products.append({
        'product_id': i,
        'product_name': fake.word().capitalize(),
        'product_description': fake.text(max_nb_chars=200)
    })

# Create sales
sales = []
for _ in range(num_sales):
    marketer_id = random.randint(1, num_marketers)  # Random marketer_id
    product_id = random.randint(1, num_products)  # Random product_id
    quantity_sold = random.randint(1, 100)  # Random quantity sold
    sale_date = fake.date_this_year()  # Random sale date within this year
    sales.append({
        'sales_id': len(sales) + 1,
        'marketer_id': marketer_id,
        'product_id': product_id,
        'quantity_sold': quantity_sold,
        'sale_date': sale_date
    })

df_marketers = pd.DataFrame(marketers)
df_products = pd.DataFrame(products)
df_sales = pd.DataFrame(sales)

df_marketers.to_sql('marketer', engine, if_exists='append', index=False)
df_products.to_sql('products', engine, if_exists='append', index=False)
df_sales.to_sql('sales', engine, if_exists='append', index=False)

print("done faker")
# Out:
# done faker

# %% [markdown]
# ## First 100 rows of each table

# %%
pd.read_sql("select * from marketer limit 100", engine)
# Out:
#     marketer_id             name  \
# 0             1   Mr. Ryan Price
# 1             2  Kathleen Nelson
# 2             3     Jasmine Love
# 3             4       Paige Wood
# 4             5    Tiffany Smith
# ..          ...              ...
# 95           96  Taylor Williams
# 96           97      James Moore
# 97           98      Eddie Moyer
# 98           99    Justin Vargas
# 99          100  Brian Hernandez
#
#                                               address          contact_number  \
# 0    076 Carla Ports Suite 303\nRobertmouth, AL 22840      475-845-4419x61753
# 1           9869 Karen Pine\nPort Mollytown, FL 09344              4578728774
# 2                    Unit 8359 Box 3189\nDPO AE 34026         +1-560-693-6854
# 3       085 Lisa Passage\nSouth Nathanmouth, TN 04291       844.628.2552x7659
# 4             3082 Johnson Lock\nGrahamside, VT 38390            578.662.6328
# ..                                                ...                     ...
# 95        382 Scott Shores\nWest Stevenview, UT 58738              4553832082
# 96   794 Johnson Loop Suite 431\nPort James, MI 97423        913-625-3390x399
# 97  32939 Stephanie Prairie\nNorth Jennifer, RI 13133  001-443-989-9796x30588
# 98        6668 Brian Circles\nSouth Carolyn, RI 74585            229.666.6975
# 99           7955 Ellis Roads\nNew Rossberg, DE 83165      359-646-5861x71572
#
#     upline_id
# 0         NaN
# 1         1.0
# 2         1.0
# 3         3.0
# 4         3.0
# ..        ...
# 95       37.0
# 96       38.0
# 97       46.0
# 98       16.0
# 99       25.0
#
# [100 rows x 5 columns]

# %%
pd.read_sql("select * from products limit 100", engine)
# Out:
#     product_id  product_name  \
# 0            1          Lose
# 1            2          Back
# 2            3       Imagine
# 3            4      Marriage
# 4            5           Cut
# 5            6      Building
# 6            7        Middle
# 7            8      Magazine
# 8            9          Wife
# 9           10       Partner
# 10          11       Soldier
# 11          12        Moment
# 12          13         Music
# 13          14         Water
# 14          15          Fire
# 15          16      Consider
# 16          17           Yet
# 17          18  Particularly
# 18          19          Four
# 19          20        Result
# 20          21      Election
# 21          22        Answer
# 22          23         Whole
# 23          24      Research
# 24          25          Safe
# 25          26    Particular
# 26          27            At
# 27          28       Article
# 28          29   Significant
# 29          30         Along
# 30          31         Cause
# 31          32     Statement
# 32          33        Public
# 33          34          Fall
# 34          35            Me
# 35          36        Before
# 36          37           Run
# 37          38       However
# 38          39         Plant
# 39          40     Establish
# 40          41       Picture
# 41          42         Under
# 42          43    Discussion
# 43          44           Run
# 44          45         Enjoy
# 45          46          Even
# 46          47         Leave
# 47          48     Condition
# 48          49       Compare
# 49          50         Quite
#
#                                   product_description
# 0   System campaign risk heavy. Suggest goal thous...
# 1   Already possible treat throw human edge answer...
# 2   Far major role know. Arrive general time busin...
# 3   Trade enjoy break see. Reason wide office gard...
# 4   Stay society writer. Table prepare court bad M...
# 5   Safe must another throughout dark. Its state s...
# 6   Start arm model out since scene.\nLikely list ...
# 7   Main he lose only build organization human. Al...
# 8   Lawyer next ask seven. Join natural operation ...
# 9   Will special lot alone. Serve TV live simply f...
# 10  Material image organization give. Friend natio...
# 11  Road energy see house. Available suddenly foll...
# 12  Simple need office agree eye. Little field up ...
# 13  Condition final happen. Fast decision recent s...
# 14  Play page work management director.\nNatural p...
# 15  Here level site local best able artist. Whom f...
# 16  Tonight often all adult. Cause one activity ta...
# 17  Dark federal speak. Relate list offer reduce c...
# 18  Former center affect realize fill. Rock almost...
# 19  Road newspaper apply blood bank listen final. ...
# 20  Will Democrat at for car model large. Kitchen ...
# 21  Bad a me land age defense official. Sense blue...
# 22  Nor price whole employee couple total. Star ci...
# 23  Loss he stay executive. Difficult record write...
# 24  Character tough health environmental position ...
# 25  Current full mouth worker property sea since. ...
# 26  Stock somebody skill himself process concern. ...
# 27  Care different be direction study. Light missi...
# 28  Story somebody tend husband. Image economy qui...
# 29  Thus western management interesting. Mean if a...
# 30  Wish lot together charge. Oil thank husband.\n...
# 31  Get continue different tell. Benefit ask adult...
# 32  Draw school tough safe. Chair become return co...
# 33  Team can what world easy. Later yeah ball insi...
# 34  Give test inside owner religious quickly every...
# 35  Spring million answer my. Marriage key off cha...
# 36  Paper four call walk. Others certain resource ...
# 37  Result technology building.\nEasy big heart fi...
# 38  Choice mention market easy growth. Off and fiv...
# 39  Window answer have make. Serve resource size.\...
# 40  Attention else operation town remain collectio...
# 41  Rule instead professional stand. Design operat...
# 42  Beat baby mouth hope program through. Sort wea...
# 43  Before history thousand impact different. Acco...
# 44  Until no compare tell indeed edge ground. But ...
# 45  Good interview car protect sense staff. Marria...
# 46  Throughout give participant politics. Experien...
# 47  For think detail body claim speak. Lose role t...
# 48  Threat PM enter present indeed sea decide. Exp...
# 49  Challenge institution along new imagine coach....

# %%
pd.read_sql("select * from sales limit 100", engine)
# Out:
#     sales_id  marketer_id  product_id  quantity_sold   sale_date
# 0          1           93          44             79  2025-01-09
# 1          2           44          35             68  2025-01-04
# 2          3           10          46             16  2025-01-12
# 3          4           69          21             83  2025-01-10
# 4          5           36          45             96  2025-01-14
# ..       ...          ...         ...            ...         ...
# 95        96           59          36             35  2025-01-03
# 96        97           49          26             85  2025-01-03
# 97        98           43           6             17  2025-01-14
# 98        99           33           7             46  2025-01-01
# 99       100           46          46             88  2025-01-14
#
# [100 rows x 5 columns]

# %% [markdown]
# ## Number of rows of each table

# %%
# %sql select COUNT(*) from marketer
# Out:
# Running query in 'postgresql://vincent:***@sampledb.c34wykcu8liz.us-east-1.rds.amazonaws.com/mlm'
# 1 rows affected.
# +-------+
# | count |
# +-------+
# |  100  |
# +-------+

# %%
# %sql select COUNT(*) from products
# Out:
# Running query in 'postgresql://vincent:***@sampledb.c34wykcu8liz.us-east-1.rds.amazonaws.com/mlm'
# 1 rows affected.
# +-------+
# | count |
# +-------+
# |   50  |
# +-------+

# %%
# %sql select COUNT(*) from sales
# Out:
# Running query in 'postgresql://vincent:***@sampledb.c34wykcu8liz.us-east-1.rds.amazonaws.com/mlm'
# 1 rows affected.
# +-------+
# | count |
# +-------+
# |  500  |
# +-------+

# %% [markdown]
# ## Rollback/Start from scratch queries

# %%
# %%sql 
# DROP TABLE IF EXISTS marketer, products, sales CASCADE;
